# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data.csv")

# %%
df
# Out:
#      title  url                                               text dead  \
# 0      NaN  NaN  That&#x27;s basically what trusts are, with a ...  NaN
# 1      NaN  NaN  Huawei had to license synopsys&#x2F;cadence&#x...  NaN
# 2      NaN  NaN  &quot;Bad men need nothing more to compass the...  NaN
# 3      NaN  NaN  A couple of years ago we lost our domain [1] d...  NaN
# 4      NaN  NaN                       Maybe it’s made of Markdown.  NaN
# 5      NaN  NaN  I used to work at the company (Mokriya) that h...  NaN
# 6      NaN  NaN  GCS - not to be confused with Google Cloud Sto...  NaN
# 7      NaN  NaN  But definitely it’s the girls’ fault, am I right?  NaN
# 8      NaN  NaN  The only people who generally have private hea...  NaN
# 9      NaN  NaN  Kind-of alluded to in the article, but if you’...  NaN
# 10     NaN  NaN  In a world where &quot;telling&quot; people is...  NaN
# 11     NaN  NaN               Sic transit gloria mundi ( ͡° ͜ʖ ͡°)  NaN
# ...

# %%
user_range = 10

# %%
def labeling():
    user_start = int(input("Hello! Please enter the index of the starting comment you would like to label:  "))
    user_end = int(input("And the index of the last comment you would like to label:  ")) +1
    for i in range(user_start, user_end):
        print(df.text[i])
        df['salty'] = input("Salty? [0/1]:  ")
        print("\n\n")

# %%
labeling()
# Out:
# Hello! Please enter the index of the starting comment you would like to label:   10
# And the index of the last comment you would like to label:   12
# In a world where &quot;telling&quot; people is enough, there is no evil.
# Salty? [0/1]:   1
# /n/n
# Sic transit gloria mundi ( ͡° ͜ʖ ͡°)
# Salty? [0/1]:   0
# /n/n
# A plain reading indicates that yes, he&#x27;s only referring to the last benchmark, which showed the 2&#x2F;3 disparity.
# Salty? [0/1]:   1
# /n/n

# %%
df.head()
# Out:
#   title  url                                               text dead  \
# 0   NaN  NaN  That&#x27;s basically what trusts are, with a ...  NaN
# 1   NaN  NaN  Huawei had to license synopsys&#x2F;cadence&#x...  NaN
# 2   NaN  NaN  &quot;Bad men need nothing more to compass the...  NaN
# 3   NaN  NaN  A couple of years ago we lost our domain [1] d...  NaN
# 4   NaN  NaN                       Maybe it’s made of Markdown.  NaN
#
#           by  score        time                timestamp     type        id  \
# 0   beerandt    NaN  1575492570  2019-12-04 20:49:30 UTC  comment  21706756
# 1     ausjke    NaN  1575247733  2019-12-02 00:48:53 UTC  comment  21678985
# 2  mgolawala    NaN  1575485493  2019-12-04 18:51:33 UTC  comment  21705572
# 3  dylanpyle    NaN  1575478916  2019-12-04 17:01:56 UTC  comment  21703980
# 4     sedatk    NaN  1575349237  2019-12-03 05:00:37 UTC  comment  21690060
#
#        parent  descendants  ranking  deleted salty
# ...
